# %% [markdown]
# # Fraud Detection Using Machine Learning
#
# This notebook demonstrates synthetic data generation, model training, and evaluation for a fraud detection workflow.

# %%
import pandas as pd
from src.data import generate_synthetic_fraud_data, split_features_target
from src.model import train_model, evaluate_model

df = generate_synthetic_fraud_data(n_samples=5000, n_features=10, fraud_ratio=0.02)
df.head()

# %%
X, y = split_features_target(df)
model = train_model(X, y)
metrics = evaluate_model(model, X, y)
metrics
